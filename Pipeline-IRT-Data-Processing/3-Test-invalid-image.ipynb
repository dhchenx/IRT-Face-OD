# %%
# Test
from IPython.display import Image, display
import flyr
root_path=r'../数据库/Thermal Image of Faces for Temperature Detection/{num}-20220708T112636Z-001/{num}'
flir_path=root_path.replace("{num}","1")+"/"+"FLIR_20220309_035116.jpg"
display(Image(filename=flir_path,width='15%'))

thermogram = flyr.unpack(flir_path)
# thermal = thermogram.kelvin  # As kelvin
thermal = thermogram.celsius  # As celsius
print(thermal)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# f:\UIBE科研\红外成像\InfraData\3-Test-invalid-image.ipynb 单元格 1 in 8
#       <a href='vscode-notebook-cell:/f%3A/UIBE%E7%A7%91%E7%A0%94/%E7%BA%A2%E5%A4%96%E6%88%90%E5%83%8F/InfraData/3-Test-invalid-image.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> flir_path=root_path.replace("{num}","1")+"/"+"FLIR_20220309_035116.jpg"
#       <a href='vscode-notebook-cell:/f%3A/UIBE%E7%A7%91%E7%A0%94/%E7%BA%A2%E5%A4%96%E6%88%90%E5%83%8F/InfraData/3-Test-invalid-image.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> display(Image(filename=flir_path,width='15%'))
# ----> <a href='vscode-notebook-cell:/f%3A/UIBE%E7%A7%91%E7%A0%94/%E7%BA%A2%E5%A4%96%E6%88%90%E5%83%8F/InfraData/3-Test-invalid-image.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> thermogram = flyr.unpack(flir_path)
# ...

# %%
# data souce: 
root_path='../数据库/thermal_image_dataset-20210815T145411Z-001/thermal_image_dataset/6'
file_path=root_path+"/"+'image_1.png'

display(Image(filename=file_path,width='15%'))
